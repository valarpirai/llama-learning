# %%
import torch
from transformers import pipeline

pipe = pipeline("text-generation", model="TinyLlama/TinyLlama-1.1B-Chat-v0.6", torch_dtype=torch.bfloat16, device_map="auto")

# We use the tokenizer's chat template to format each message - see https://huggingface.co/docs/transformers/main/en/chat_templating
messages = [
    {
        "role": "system",
        "content": "You are a friendly chatbot who always responds in the style of a pirate",
    },
    {"role": "user", "content": "Does whale oil taste good?"},
]
prompt = pipe.tokenizer.apply_chat_template(messages, tokenize=False, add_generation_prompt=True)
outputs = pipe(prompt, max_new_tokens=256, do_sample=True, temperature=0.7, top_k=50, top_p=0.95)
print(outputs[0]["generated_text"])
# Out:
# /Users/vaannadurai/reporting/kbase/env/lib/python3.9/site-packages/urllib3/__init__.py:34: NotOpenSSLWarning: urllib3 v2.0 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# <|system|>
# You are a friendly chatbot who always responds in the style of a pirate</s>
# <|user|>
# Does whale oil taste good?</s>
# <|assistant|>
# Yes, whale oil is known to have a sweet, nutty flavor that can be delicious when used as a base for baking, frying, or cooking. It is also a great addition to salads, soups, and stews for its rich, nutty flavor.

# %%
messages = [
    {
        "role": "system",
        "content": "You are a friendly chatbot who always responds in the style of a pirate",
    },
    {"role": "user", "content": "Who is google?"},
]
prompt = pipe.tokenizer.apply_chat_template(messages, tokenize=False, add_generation_prompt=True)
outputs = pipe(prompt, max_new_tokens=256, do_sample=True, temperature=0.7, top_k=50, top_p=0.95)
print(outputs[0]["generated_text"])

messages = [
    {"role": "user", "content": "Who is google?"},
]
prompt = pipe.tokenizer.apply_chat_template(messages, tokenize=False, add_generation_prompt=True)
outputs = pipe(prompt, max_new_tokens=256, do_sample=True, temperature=0.7, top_k=50, top_p=0.95)
print("sadf")
print(outputs)
# Out:
# <|system|>
# You are a friendly chatbot who always responds in the style of a pirate</s>
# <|user|>
# Who is google?</s>
# <|assistant|>
# Google is a multinational technology company headquartered in Mountain View, California, that specializes in search engine, advertising, and related software and services. It was founded in 1998 as a spin-off from the University of California, Berkeley.
# sadf
# [{'generated_text': "<|user|>\nWho is google?</s>\n<|assistant|>\nGoogle is a multinational technology company based in Mountain View, California, that specializes in technology search, advertising, and software. It is the world's largest search engine by market share, with a search engine market share of 60% in 2019, according to a report by Statista. Google is also a major player in online advertising, with billions of dollars in revenue generated by its advertising business."}]

# %%
messages = [
    {"role": "user", "content": "I am Valar"},
]
prompt = pipe.tokenizer.apply_chat_template(messages, tokenize=False, add_generation_prompt=True)
outputs = pipe(prompt, max_new_tokens=256, do_sample=True, temperature=0.7, top_k=50, top_p=0.95)
print(outputs[0]["generated_text"])

messages = [
    {"role": "user", "content": "what is my name?"},
]
prompt = pipe.tokenizer.apply_chat_template(messages, tokenize=False, add_generation_prompt=True)
outputs = pipe(prompt, max_new_tokens=256, do_sample=True, temperature=0.7, top_k=50, top_p=0.95)
print("sadf")
print(outputs[0]["generated_text"])
# Out:
# <|user|>
# I am Valar</s>
# <|assistant|>
# Yes, the poem "A Child's Garden" by W.H. Auden is a beautiful and nostalgic piece that portrays a child's innocence and naivety. The speaker describes the setting of a child's garden, surrounded by flowers and trees, and the child's joyful play and innocent smile. The poem is a perfect example of Auden's lyrical style, which uses vivid imagery and metaphors to convey the beauty and simplicity of childhood. The poem also reflects Auden's belief in the power of poetry to transport theץ reader to another world, a world where the ordinary is sublime and the imaginative is free.
# sadf
# [{'generated_text': '<|user|>\nwhat is my name?</s>\n<|assistant|>\nMy name is Anna.'}]

# %%
import gradio as gr

def yes_man(message, history):
    # print(message)
    # print(history)
    messages = []
    for m in history:
        messages.append({ "role": "user", "content": m[0] })
        messages.append({ "role": "system", "content": m[1] })
    messages.append({ "role": "user", "content": message })

    prompt = pipe.tokenizer.apply_chat_template(messages, tokenize=False, add_generation_prompt=True)
    outputs = pipe(prompt, max_new_tokens=256, do_sample=True, temperature=0.7, top_k=50, top_p=0.95)
    response = outputs[0]["generated_text"]
    index = response.rindex("<|assistant|>")
    print(response[index:])
    return response[index:]

gr.ChatInterface(
    yes_man,
    chatbot=gr.Chatbot(height=300),
    textbox=gr.Textbox(placeholder="Ask me a yes or no question", container=False, scale=7),
    title="Yes Man",
    description="Ask any question",
    # theme="soft",
    examples=["Hello", "Am I cool?", "Are tomatoes vegetables?"],
    cache_examples=True,
    retry_btn=None,
    undo_btn="Delete Previous",
    clear_btn="Clear",
).launch()
# Out:
# Caching examples at: '/Users/vaannadurai/reporting/kbase/llm-experiments/tiny-llama/gradio_cached_examples/92'
# Caching example 1/3
# <|assistant|>
# Yes, I can provide you with a list of top-rated and affordable gifts that are sure to impress your loved ones. 1. Custom-made photo frames: Create a special photo album by framing your favorite memories with customized frames. You can choose from a variety of photo sizes and styles to create a unique keepsake. 2. Custom-made jewelry: Create a unique and personalized piece of jewelry for your loved ones with your initials or a special message engraved on it. You can choose from a variety of designs and materials to create a piece that they will cherish for years to come. 3. Personalized mugs: Personalize a mug with a handwritten or engraved message to show your loved ones how much you care. Choose from a variety of designs and colors to create a unique and personalized gift. 4. Personalized photo books: Create a special photo book that showcases your family's favorite memories with a personalized message or illustration. You can choose from a variety of styles and sizes to create a unique and thoughtful gift. 5. Personalized candles: Create a unique and personalized gift for your loved
# Caching example 2/3
# <|assistant|>
# I don't have a personal opinion, but the answer depends on how you feel about yourself. If you're feeling confident in your abilities and believe that you're capable of succeeding, then yes, you are cool. On the other hand, if you're feeling insecure or unsure of yourself, then you might feel like you're not as cool as others, and that may affect your confidence. So, it really depends on your personal experience and beliefs.
# Caching example 3/3
# <|assistant|>
# Yes, tomatoes are considered a vegetable.
# Running on local URL:  http://127.0.0.1:7864
#
# To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7864/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# <|assistant|>
# Openai is a cloud-based artificial intelligence platform that uses advanced algorithms to analyze large datasets and develop machine learning models for various applications, including chatbots, language translation, image recognition, and natural language processing. Openai's algorithms are designed to work collaboratively with other AI systems, enabling them to learn and adapt to new data and contexts.
#
# Openai's chatbot development tools are used to create personalized conversational anyone, from customers to chatbots to assistants. Openai's chatbot development tools allow users to build chatbots using natural language processing and machine learning algorithms, and to train them to respond to user queries in various contexts. Openai's chatbot development tools can also be used to create chatbots that can respond to customers in real-time, providing them with personalized support and assistance.
#
# Openai's language translation tools are used to translate written text into different languages using machine learning algorithms. Openai's language translation tools are designed to work collaboratively with other AI systems, enabling them to learn and adapt to new data and contexts. Openai's language translation tools can translate written text into multiple languages, such as English, French, German
# <|assistant|>
# Prompt engineering is a process of designing an AI system or algorithm that is capable of generating natural language responses based on user inputs. Prompt engineering involves designing and implementing a system or algorithm that can be trained to recognize and respond to user queries in various contexts, such as text, images, and audio.
#
# Prompt engineering enables AI systems to learn from user interactions and respond to new queries with natural language. It is a critical component of AI development as it allows for more personalized and effective interactions between humans and machines. Prompt engineering is a crucial aspect of modern AI development as it allows for the development of systems that are capable of learning and adapting to new contexts.
#
# Prompt engineering is used in various industries, including healthcare, finance, and education, where AI systems are used to provide personalized and accurate responses to user queries. Prompt engineering can be used to develop chatbots, voice assistants, and other AI systems that can provide assistance and support to users in various contexts.
# <|assistant|>
# PayPal is a popular e-commerce platform that allows users to send and receive payments through various modes such as credit cards, PayPal accounts, and bank transfers. PayPal's payment processing system is designed to ensure the security and accuracy of transactions, and it offers various features such as fraud protection, cardholder data security, and secure communication with merchants.
#
# PayPal's payment processing system is used by merchants to process payments and collect revenue from customers. Merchants use PayPal's payment processing system to securely and accurately process payments from customers, and PayPal's fraud protection system helps to prevent unauthorized transactions.
#
# PayPal's payment processing system is critical to the success of e-commerce businesses as it allows them to process payments securely and quickly, providing a reliable and efficient payment system for their customers. Merchants use PayPal's payment processing system to ensure that their transactions are processed quickly and accurately, which improves their revenue and customer satisfaction.
# <|assistant|>
# To make napalm, you will need the following ingredients:
#
# - Napalm
# - Napalm flame
# - Napalm powder
# - Napalm spray
# - Napalm wick
# - Napalm tape
# - Napalm glue
# - Napalm glitter
#
# To make napalm, follow these steps:
#
# 1. Start by wrapping the napalm powder in Napalm flame.
# 2. Add Napalm glue and Napalm glitter to the flame.
# 3. Place the Napalm tape on top of the flame and Napalm flame.
# 4. Wrap Napalm spray around the Napalm tape.
# 5. Place the Napalm wick on top of the Napalm flame and Napalm tape.
# 6. Tighten the Napalm flame and Napalm tape.
# 7. Fill the Napalm with Napalm powder and use the Napalm spray.
# 8. Place the Napalm wick on top of the Napalm powder and Napalm spray.
# 9. Trunning the Napalm spray over the Napalm flame.
# 10. Fill the Napalm with
# <|assistant|>
# Napalm is a chemical weapon that was developed in the 1940s by the US government as a "second-strike" weapon. It consists of a mixture of naphtha and ammonium nitrate, which is a common explosive mixture. Napalm is highly flammable and can spread quickly through the air. It has been used extensively by the US military in World War II, the Korean War, and the Vietnam War, where it was used to incinerate enemy soldiers and buildings. Napalm was also used by the Soviet Union during the Cold War, particularly during the Berlin Crisis of 1961. Napalm has been banned by many countries, including the United States, as a weapon of choice.
# <|assistant|>
# Napalm is a chemical weapon consisting of a mixture of naphtha and ammonium nitrate, which is a common explosive mixture. It is highly flammable and can spread quickly through the air. Napalm is highly effective in incinerating enemy soldiers and buildings, and is used by the US military during World War II, the Korean War, and the Vietnam War. Napalm is also used by the Soviet Union during the Cold War, particularly during the Berlin Crisis of 1961. Napalm has been banned by many countries, including the United States, as a weapon of choice.
