# %% [markdown]
# ## Basic Multi-LLM Workflows
#
# This notebook demonstrates three simple multi-LLM workflows. They trade off cost or latency for potentially improved task performances:
#
# 1. **Prompt-Chaining**: Decomposes a task into sequential subtasks, where each step builds on previous results
# 2. **Parallelization**: Distributes independent subtasks across multiple LLMs for concurrent processing
# 3. **Routing**: Dynamically selects specialized LLM paths based on input characteristics
#
# Note: These are sample implementations meant to demonstrate core concepts - not production code.

# %%
from concurrent.futures import ThreadPoolExecutor
from typing import List, Dict, Callable
from util import llm_call, extract_xml

# %%
def chain(input: str, prompts: List[str]) -> str:
    """Chain multiple LLM calls sequentially, passing results between steps."""
    result = input
    for i, prompt in enumerate(prompts, 1):
        print(f"\nStep {i}:")
        result = llm_call(f"{prompt}\nInput: {result}")
        print(result)
    return result

def parallel(prompt: str, inputs: List[str], n_workers: int = 3) -> List[str]:
    """Process multiple inputs concurrently with the same prompt."""
    with ThreadPoolExecutor(max_workers=n_workers) as executor:
        futures = [executor.submit(llm_call, f"{prompt}\nInput: {x}") for x in inputs]
        return [f.result() for f in futures]

def route(input: str, routes: Dict[str, str]) -> str:
    """Route input to specialized prompt using content classification."""
    # First determine appropriate route using LLM with chain-of-thought
    print(f"\nAvailable routes: {list(routes.keys())}")
    selector_prompt = f"""
    Analyze the input and select the most appropriate support team from these options: {list(routes.keys())}
    First explain your reasoning, then provide your selection in this XML format:

    <reasoning>
    Brief explanation of why this ticket should be routed to a specific team.
    Consider key terms, user intent, and urgency level.
    </reasoning>

    <selection>
    The chosen team name
    </selection>

    Input: {input}""".strip()
    
    route_response = llm_call(selector_prompt)
    reasoning = extract_xml(route_response, 'reasoning')
    route_key = extract_xml(route_response, 'selection').strip().lower()
    
    print("Routing Analysis:")
    print(reasoning)
    print(f"\nSelected route: {route_key}")
    
    # Process input with selected specialized prompt
    selected_prompt = routes[route_key]
    return llm_call(f"{selected_prompt}\nInput: {input}")

# %% [markdown]
# ## Example Usage
#
# Below are practical examples demonstrating each workflow:
# 1. Chain workflow for structured data extraction and formatting
# 2. Parallelization workflow for stakeholder impact analysis
# 3. Route workflow for customer support ticket handling

# %%
# Example 1: Chain workflow for structured data extraction and formatting
# Each step progressively transforms raw text into a formatted table

data_processing_steps = [
    """Extract only the numerical values and their associated metrics from the text.
    Format each as 'value: metric' on a new line.
    Example format:
    92: customer satisfaction
    45%: revenue growth""",
    
    """Convert all numerical values to percentages where possible.
    If not a percentage or points, convert to decimal (e.g., 92 points -> 92%).
    Keep one number per line.
    Example format:
    92%: customer satisfaction
    45%: revenue growth""",
    
    """Sort all lines in descending order by numerical value.
    Keep the format 'value: metric' on each line.
    Example:
    92%: customer satisfaction
    87%: employee satisfaction""",
    
    """Format the sorted data as a markdown table with columns:
    | Metric | Value |
    |:--|--:|
    | Customer Satisfaction | 92% |"""
]

report = """
Q3 Performance Summary:
Our customer satisfaction score rose to 92 points this quarter.
Revenue grew by 45% compared to last year.
Market share is now at 23% in our primary market.
Customer churn decreased to 5% from 8%.
New user acquisition cost is $43 per user.
Product adoption rate increased to 78%.
Employee satisfaction is at 87 points.
Operating margin improved to 34%.
"""

print("\nInput text:")
print(report)
formatted_result = chain(report, data_processing_steps)
print(formatted_result)
# Out:
# Input text:
#
# Q3 Performance Summary:
# Our customer satisfaction score rose to 92 points this quarter.
# Revenue grew by 45% compared to last year.
# Market share is now at 23% in our primary market.
# Customer churn decreased to 5% from 8%.
# New user acquisition cost is $43 per user.
# Product adoption rate increased to 78%.
# Employee satisfaction is at 87 points.
# Operating margin improved to 34%.
#
#
# Step 1:
# Here are the extracted numerical values and their associated metrics:
#
# 92: customer satisfaction
# 45%: revenue growth
# 23%: market share
# 5%: customer churn
# $43: new user acquisition cost
# 78%: product adoption rate
# 87: employee satisfaction
# 34%: operating margin
#
# Step 2:
# Here is the reformatted list with numerical values converted to percentages where possible:
#
# 92%: customer satisfaction
# 45%: revenue growth
# 23%: market share
# 5%: customer churn
# 43$: new user acquisition cost ($43 / 100)
# 78%: product adoption rate
# 87%: employee satisfaction
# 34%: operating margin
#
# Step 3:
# Here is the sorted list in descending order by numerical value:
#
# 92%: customer satisfaction
# 87%: employee satisfaction
# 78%: product adoption rate
# 45%: revenue growth
# 43$: new user acquisition cost ($43 / 100)
# 34%: operating margin
# 23%: market share
# 5%: customer churn
#
# Step 4:
# Here is the formatted markdown table:
#
# | Metric | Value |
# |:--|--:|
# | Customer Satisfaction | 92% |
# | Employee Satisfaction | 87% |
# | Product Adoption Rate | 78% |
# | Revenue Growth | 45% |
# | New User Acquisition Cost | $43 / 100 |
# | Operating Margin | 34% |
# | Market Share | 23% |
# | Customer Churn | 5% |
#
# Let me know if you'd like to sort the data in any other way!
# Here is the formatted markdown table:
#
# | Metric | Value |
# |:--|--:|
# | Customer Satisfaction | 92% |
# | Employee Satisfaction | 87% |
# | Product Adoption Rate | 78% |
# | Revenue Growth | 45% |
# | New User Acquisition Cost | $43 / 100 |
# | Operating Margin | 34% |
# | Market Share | 23% |
# | Customer Churn | 5% |
#
# Let me know if you'd like to sort the data in any other way!

# %%
# Example 2: Parallelization workflow for stakeholder impact analysis
# Process impact analysis for multiple stakeholder groups concurrently

stakeholders = [
    """Customers:
    - Price sensitive
    - Want better tech
    - Environmental concerns""",
    
    """Employees:
    - Job security worries
    - Need new skills
    - Want clear direction""",
    
    """Investors:
    - Expect growth
    - Want cost control
    - Risk concerns""",
    
    """Suppliers:
    - Capacity constraints
    - Price pressures
    - Tech transitions"""
]

impact_results = parallel(
    """Analyze how market changes will impact this stakeholder group.
    Provide specific impacts and recommended actions.
    Format with clear sections and priorities.""",
    stakeholders
)

for result in impact_results:
    print(result)
# Out:
# **Customer Stakeholder Analysis**
#
# The customer stakeholder group consists of price-sensitive individuals who prioritize better technology and environmental concerns. To analyze how market changes will impact this stakeholder group, we'll examine potential shifts in their needs, preferences, and behaviors.
#
# **Market Changes:**
#
# 1. **Rising concerns about climate change**: Governments and organizations are implementing stricter regulations to reduce carbon emissions.
# 2. **Advancements in renewable energy**: Increasing adoption of solar, wind, and other sustainable energy sources is expected to drive demand for eco-friendly products.
# 3. **Growing tech literacy**: Customers are becoming more aware of the benefits and limitations of technology, driving demand for better-performing devices.
#
# **Potential Impacts on Customer Stakeholder Group:**
#
# 1. **Price sensitivity remains high**: As prices for sustainable technologies decrease, customers may be more willing to pay a premium for eco-friendly products.
# 2. **Increased demand for better tech**: With advancements in renewable energy and growing tech literacy, customers will prioritize devices with improved performance, battery life, and features that enhance their daily lives.
# 3. **Environmental concerns drive product development**: Manufacturers will focus on creating sustainable products, packaging, and supply chains to appeal to environmentally conscious customers.
#
# **Recommended Actions:**
#
# **For Companies:**
#
# 1. **Invest in research and development (R&D)**: Focus on developing innovative, eco-friendly technologies that address customer needs.
# 2. **Optimize product design and sustainability**: Incorporate sustainable materials, reduce waste, and minimize carbon footprint in production processes.
# 3. **Implement environmentally responsible supply chains**: Source materials responsibly and ensure suppliers adhere to environmental standards.
#
# **For Manufacturers:**
#
# 1. **Offer tiered pricing options**: Provide price-sensitive customers with more affordable eco-friendly products while maintaining premium offerings for those willing to pay a higher price.
# 2. **Develop targeted marketing campaigns**: Focus on highlighting the benefits of better tech, sustainable materials, and environmentally responsible practices in marketing efforts.
# 3. **Establish transparency and accountability**: Clearly communicate environmental impact and supply chain practices through reporting and certification programs.
#
# **For Governments and Policymakers:**
#
# 1. **Implement regulations and incentives**: Establish policies that encourage manufacturers to adopt sustainable practices and invest in eco-friendly technologies.
# 2. **Invest in public education campaigns**: Raise awareness about the importance of sustainable consumption, climate change mitigation, and environmental responsibility among the general public.
# 3. **Support research and development funding**: Provide grants or tax breaks for companies investing in R&D for sustainable technologies.
#
# **Priorities:**
#
# 1. **Environmental sustainability**: Addressing customer concerns about climate change and reducing waste will remain a top priority.
# 2. **Technology innovation**: Developing better-performing devices with improved features and performance will be crucial to maintaining customer loyalty.
# 3. **Price sensitivity management**: Balancing affordability with premium offerings while addressing environmental concerns will require careful consideration.
#
# By prioritizing these areas, companies can effectively adapt to market changes and meet the evolving needs of their price-sensitive customer stakeholder group.
# **Market Analysis Impact on Stakeholders: Employees**
#
# **Introduction**
#
# The market changes will have significant implications for employees, impacting their job security, need for new skills, and desire for clear direction. This analysis aims to identify specific impacts and provide recommended actions for managers and organizations.
#
# **Impacts on Job Security**
#
# 1. **Changes in Industry Demand**: Shifts in industry demand may lead to reduced staffing needs or increased automation, potentially impacting job security.
# 2. **Economic Uncertainty**: Market fluctuations can result in economic downturns, affecting employment opportunities and job stability.
# 3. **Global Competition**: Increased global competition can lead to a more competitive job market, making it challenging for employees to find stable employment.
#
# **Impacts on Need for New Skills**
#
# 1. **Technological Advancements**: Rapid technological changes require workers to acquire new skills to remain employable.
# 2. **Changing Job Requirements**: Shifts in industry demand may necessitate new skill sets, making existing skills obsolete.
# 3. **Lifelong Learning**: Employees must invest time and resources in continuous learning to stay relevant in the job market.
#
# **Impacts on Desire for Clear Direction**
#
# 1. **Uncertainty and Ambiguity**: Market changes can create uncertainty, leading to a need for clear direction and purpose from managers and organizations.
# 2. **Communication Challenges**: Effective communication is crucial during times of change, ensuring employees understand their roles and responsibilities.
# 3. **Trust and Confidence**: Managers must foster trust and confidence with employees, providing clear guidance and support during periods of uncertainty.
#
# **Recommended Actions**
#
# ### For Employees:
#
# 1. **Upskill and Reskill**: Invest in continuous learning to adapt to changing industry demands and technological advancements.
# 2. **Stay Agile and Adaptable**: Develop flexibility and resilience to navigate uncertain market conditions.
# 3. **Communicate with Managers**: Establish open channels of communication to ensure clear understanding of job requirements, expectations, and goals.
#
# ### For Managers:
#
# 1. **Provide Clear Direction**: Offer transparent guidance and support during times of change, ensuring employees understand their roles and responsibilities.
# 2. **Foster a Culture of Trust**: Build trust with employees by being approachable, transparent, and responsive to their concerns.
# 3. **Prioritize Employee Development**: Invest in employee training and development programs to enhance skills and competitiveness.
#
# ### For Organizations:
#
# 1. **Emphasize Continuous Learning**: Implement ongoing learning programs to support employee upskilling and reskilling.
# 2. **Adapt to Market Changes**: Develop strategies to navigate market fluctuations, ensuring business continuity and minimizing job losses.
# 3. **Communicate Effectively**: Establish open channels of communication with employees, stakeholders, and the wider community to manage expectations and build trust.
#
# **Priorities**
#
# 1. **Short-term Focus**: Prioritize immediate needs for clear direction, effective communication, and employee development.
# 2. **Long-term Strategy**: Develop strategies for adapting to market changes, investing in employee upskilling, and fostering a culture of trust and confidence.
# 3. **Continuous Monitoring**: Regularly assess the impact of market changes on employees and organizations, making adjustments as needed.
#
# By understanding these impacts and taking proactive steps, managers and organizations can mitigate the effects of market changes on employees, ensuring their job security, new skills development, and clear direction.
# **Market Analysis for Investors**
#
# The following analysis highlights the potential impacts of market changes on investors, specifically those expecting growth, seeking cost control, and concerned about risk.
#
# **Impact 1: Economic Downturn**
#
# * **Expectation vs. Reality:** The economy is expected to grow at a moderate pace, but there is a risk of a downturn due to global trade tensions and rising interest rates.
# * **Impact on Investors:** Growth may be slower than expected, affecting investor returns.
# * **Recommended Action:**
#  + Diversify investments across sectors to minimize exposure to any one market.
#  + Increase cash reserves to take advantage of potential buying opportunities.
#  + Re-evaluate investment strategies and adjust allocations as needed.
#
# **Impact 2: Regulatory Changes**
#
# * **Expectation vs. Reality:** There may be changes in regulations affecting industries such as technology, finance, or healthcare.
# * **Impact on Investors:** Compliance costs may increase, reducing profitability for some companies.
# * **Recommended Action:**
#  + Monitor regulatory updates and adjust investment strategies accordingly.
#  + Consider investing in companies that are well-positioned to benefit from regulatory changes.
#  + Diversify across sectors to minimize exposure to any one industry.
#
# **Impact 3: Technological Disruption**
#
# * **Expectation vs. Reality:** Technology is expected to continue driving innovation, but there may be significant disruption to traditional industries.
# * **Impact on Investors:** Companies that fail to adapt to technological changes may struggle to remain competitive.
# * **Recommended Action:**
#  + Invest in companies with strong technological capabilities and a track record of innovation.
#  + Consider investing in emerging technologies such as AI, blockchain, or renewable energy.
#  + Diversify across sectors to minimize exposure to any one industry.
#
# **Impact 4: Inflation**
#
# * **Expectation vs. Reality:** Inflation is expected to be low, but there may be unexpected increases due to global events.
# * **Impact on Investors:** Higher inflation can erode purchasing power and reduce the value of investments.
# * **Recommended Action:**
#  + Invest in assets that historically perform well during periods of inflation, such as real estate or commodities.
#  + Consider investing in companies with pricing power and strong profit margins.
#  + Diversify across sectors to minimize exposure to any one industry.
#
# **Impact 5: Global Events**
#
# * **Expectation vs. Reality:** Global events such as natural disasters or conflicts may impact markets and economies.
# * **Impact on Investors:** Market volatility and economic disruption can lead to reduced investor returns.
# * **Recommended Action:**
#  + Diversify across sectors and geographic regions to minimize exposure to any one market.
#  + Consider investing in companies with strong balance sheets and cash reserves.
#  + Re-evaluate investment strategies and adjust allocations as needed.
#
# **Priorities:**
#
# 1. **Diversification:** Spread investments across sectors, industries, and geographic regions to minimize exposure to any one market or industry.
# 2. **Risk Management:** Invest in companies with strong financials, innovative technologies, and pricing power to mitigate risk.
# 3. **Adaptability:** Monitor regulatory updates, technological changes, and global events to adjust investment strategies accordingly.
#
# By understanding these potential impacts and taking recommended actions, investors can better navigate the changing market landscape and achieve their goals.
# **Supplier Analysis**
#
# The supplier stakeholder group is expected to face significant market changes that may impact their operations, profitability, and competitiveness. The following analysis outlines the potential impacts on suppliers, specific effects they can expect, recommended actions, and prioritization of strategies.
#
# **Section 1: Capacity Constraints**
#
# * **Impact:** Increased demand for low-cost production capacity may lead to a shortage of available resources, exacerbating existing capacity constraints.
# * **Effects:** Suppliers may struggle to meet customer demands, leading to reduced revenue and profitability. Limited capacity can also result in longer delivery times, decreased customer satisfaction, and potential supply chain disruptions.
# * **Recommended Actions:**
# 	+ Invest in capacity expansion or outsourcing to mitigate resource constraints.
# 	+ Implement flexible production systems to accommodate changing demand patterns.
# 	+ Develop partnerships with other suppliers to share resources and expertise.
#
# **Section 2: Price Pressures**
#
# * **Impact:** Rising material costs, transportation fees, and labor expenses may lead to increased pressure on suppliers' profit margins.
# * **Effects:** Suppliers may need to absorb higher costs or pass them on to customers through price increases. Reduced profitability can impact their ability to invest in innovation, R&D, and employee development.
# * **Recommended Actions:**
# 	+ Diversify revenue streams by exploring new markets, products, or services.
# 	+ Implement cost-saving measures, such as process automation or supply chain optimization.
# 	+ Negotiate with customers to secure better pricing terms or volume discounts.
#
# **Section 3: Tech Transitions**
#
# * **Impact:** Adoption of emerging technologies, such as Industry 4.0 or IoT, may require suppliers to invest in new equipment, software, and skills.
# * **Effects:** Suppliers may need to upgrade their capabilities to remain competitive, which can be resource-intensive and costly. Failure to adapt may result in reduced competitiveness, revenue loss, and decreased customer satisfaction.
# * **Recommended Actions:**
# 	+ Allocate resources for technology adoption and skill development.
# 	+ Collaborate with customers to identify priority areas for technological advancements.
# 	+ Develop strategic partnerships with tech-savvy suppliers or service providers.
#
# **Prioritization of Strategies:**
#
# Based on the analysis, the recommended prioritization of strategies for suppliers is:
#
# 1. **Capacity expansion or outsourcing**: Mitigating capacity constraints is essential to maintaining competitiveness and meeting customer demands.
# 2. **Cost-saving measures**: Implementing cost-saving measures can help suppliers absorb rising costs and maintain profitability.
# 3. **Technology adoption**: Investing in emerging technologies can enable suppliers to stay competitive, improve efficiency, and enhance customer satisfaction.
#
# **Conclusion:**
#
# The supplier stakeholder group faces significant market changes that require adaptability and strategic planning. By prioritizing capacity expansion, cost-saving measures, and technology adoption, suppliers can mitigate the impacts of these changes and maintain their competitiveness in a rapidly evolving market.

# %%
# Example 3: Route workflow for customer support ticket handling
# Route support tickets to appropriate teams based on content analysis

support_routes = {
    "billing": """You are a billing support specialist. Follow these guidelines:
    1. Always start with "Billing Support Response:"
    2. First acknowledge the specific billing issue
    3. Explain any charges or discrepancies clearly
    4. List concrete next steps with timeline
    5. End with payment options if relevant
    
    Keep responses professional but friendly.
    
    Input: """,
    
    "technical": """You are a technical support engineer. Follow these guidelines:
    1. Always start with "Technical Support Response:"
    2. List exact steps to resolve the issue
    3. Include system requirements if relevant
    4. Provide workarounds for common problems
    5. End with escalation path if needed
    
    Use clear, numbered steps and technical details.
    
    Input: """,
    
    "account": """You are an account security specialist. Follow these guidelines:
    1. Always start with "Account Support Response:"
    2. Prioritize account security and verification
    3. Provide clear steps for account recovery/changes
    4. Include security tips and warnings
    5. Set clear expectations for resolution time
    
    Maintain a serious, security-focused tone.
    
    Input: """,
    
    "product": """You are a product specialist. Follow these guidelines:
    1. Always start with "Product Support Response:"
    2. Focus on feature education and best practices
    3. Include specific examples of usage
    4. Link to relevant documentation sections
    5. Suggest related features that might help
    
    Be educational and encouraging in tone.
    
    Input: """
}

# Test with different support tickets
tickets = [
    """Subject: Can't access my account
    Message: Hi, I've been trying to log in for the past hour but keep getting an 'invalid password' error. 
    I'm sure I'm using the right password. Can you help me regain access? This is urgent as I need to 
    submit a report by end of day.
    - John""",
    
    """Subject: Unexpected charge on my card
    Message: Hello, I just noticed a charge of $49.99 on my credit card from your company, but I thought
    I was on the $29.99 plan. Can you explain this charge and adjust it if it's a mistake?
    Thanks,
    Sarah""",
    
    """Subject: How to export data?
    Message: I need to export all my project data to Excel. I've looked through the docs but can't
    figure out how to do a bulk export. Is this possible? If so, could you walk me through the steps?
    Best regards,
    Mike"""
]

print("Processing support tickets...\n")
for i, ticket in enumerate(tickets, 1):
    print(f"\nTicket {i}:")
    print("-" * 40)
    print(ticket)
    print("\nResponse:")
    print("-" * 40)
    response = route(ticket, support_routes)
    print(response)
# Out:
# Processing support tickets...
#
#
# Ticket 1:
# ----------------------------------------
# Subject: Can't access my account
#     Message: Hi, I've been trying to log in for the past hour but keep getting an 'invalid password' error.
#     I'm sure I'm using the right password. Can you help me regain access? This is urgent as I need to
#     submit a report by end of day.
#     - John
#
# Response:
# ----------------------------------------
#
# Available routes: ['billing', 'technical', 'account', 'product']
# Routing Analysis:
#
# This issue is clearly related to account access and authentication problems. The user is experiencing login difficulties with their password, which is a core account security and access issue. While there might be technical aspects involved, the primary concern is account access restoration. The urgency expressed by the user and the nature of the problem (password/login issues) makes this a typical account support case. Account team specialists are best equipped to handle password resets, account verification, and access restoration while following proper security protocols.
#
#
# Selected route: account
# Account Support Response:
#
# Dear John,
#
# I understand you're experiencing login issues and have an urgent deadline. We'll need to verify your identity before proceeding with account recovery.
#
# Immediate Steps to Take:
# 1. Clear your browser cache and cookies
# 2. Ensure CAPS LOCK is not enabled
# 3. Try accessing from a private/incognito window
#
# If still unsuccessful, initiate account recovery:
# 1. Visit the secure password reset page: [Reset Portal URL]
# 2. Click "Forgot Password"
# 3. Enter your email address
# 4. Follow verification instructions sent to your registered email
# 5. Choose a new strong password
#
# SECURITY VERIFICATION REQUIRED:
# To protect your account, you'll need to provide:
# - Account email address
# - Date of last successful login
# - Any two-factor authentication backup codes (if enabled)
#
# ⚠️ IMPORTANT SECURITY WARNINGS:
# - Never share passwords or verification codes
# - Beware of similar-looking phishing emails
# - Use unique passwords for each account
#
# Expected Resolution Time:
# - Password reset: 5-10 minutes
# - Account verification: Up to 1 hour
# - Support team response: Within 2 hours
#
# If you cannot complete these steps or don't receive verification emails, contact our security team at [secure contact information] with your account details.
#
# Regards,
# Account Security Team
#
# P.S. Once resolved, we strongly recommend enabling two-factor authentication for additional security.
#
# Ticket 2:
# ----------------------------------------
# Subject: Unexpected charge on my card
#     Message: Hello, I just noticed a charge of $49.99 on my credit card from your company, but I thought
#     I was on the $29.99 plan. Can you explain this charge and adjust it if it's a mistake?
#     Thanks,
#     Sarah
#
# Response:
# ----------------------------------------
#
# Available routes: ['billing', 'technical', 'account', 'product']
# Routing Analysis:
#
# This is clearly a billing-related inquiry for several reasons:
# 1. The user is questioning a specific charge amount ($49.99)
# 2. They're comparing it to their expected plan price ($29.99)
# 3. They're requesting explanation of charges and potential adjustment
# 4. The issue involves credit card charges and pricing plans
# 5. There's no mention of technical issues, product features, or account access problems
#
# This is a straightforward billing dispute that requires access to payment records and the ability to process refunds or adjustments if needed.
#
#
# Selected route: billing
# Billing Support Response:
#
# Dear Sarah,
#
# I understand your concern about the unexpected charge of $49.99 when you were expecting to be billed $29.99.
#
# After reviewing the billing details, this difference typically occurs when an account transitions from our Basic plan ($29.99) to our Premium plan, often due to either:
# - An automatic upgrade based on usage
# - A plan change request that may have been initiated
# - The end of a promotional period
#
# Here are the next steps to resolve this:
#
# 1. Within 1 business day: I will conduct a detailed audit of your account history to confirm when and why the plan change occurred
# 2. By tomorrow: You'll receive an email with the complete billing breakdown
# 3. Within 48 hours: If we confirm this was an error, we'll process a refund of $20 (the difference between plans)
#
# Payment Options:
# - If this charge was indeed incorrect, we can either:
#   * Issue a direct refund to your credit card (3-5 business days)
#   * Apply a $20 credit to your next billing cycle
#
# Please let me know your preferred refund method if we determine this was charged in error.
#
# Is there anything else you need clarification on regarding your billing?
#
# Best regards,
# Billing Support Team
#
# Ticket 3:
# ----------------------------------------
# Subject: How to export data?
#     Message: I need to export all my project data to Excel. I've looked through the docs but can't
#     figure out how to do a bulk export. Is this possible? If so, could you walk me through the steps?
#     Best regards,
#     Mike
#
# Response:
# ----------------------------------------
#
# Available routes: ['billing', 'technical', 'account', 'product']
# Routing Analysis:
#
# This is clearly a technical/functional question about using a product feature (data export). The user is requesting specific instructions on how to perform a task within the system. Key terms like "export," "data," "bulk export," and the request for step-by-step guidance indicate this is a technical how-to question. This isn't related to billing, account management, or product feedback - it's about understanding how to use an existing feature.
#
#
# Selected route: technical
# Technical Support Response:
#
# I'll help you export your project data to Excel. Here's the step-by-step process:
#
# Steps to Export Data:
# 1. Log into your project dashboard
# 2. Navigate to "Project Settings" in the top right corner
# 3. Select "Data Management" from the dropdown menu
# 4. Click the "Export" tab
# 5. Choose "Bulk Export" option
# 6. Select data range and specific data fields you want to export
# 7. Choose "Excel (.xlsx)" as the export format
# 8. Click "Generate Export"
# 9. Wait for the system to process (may take several minutes for large datasets)
# 10. Download the exported file when complete
#
# System Requirements:
# - Supported browsers: Chrome 90+, Firefox 88+, Edge 91+
# - Minimum 4GB RAM recommended for large exports
# - Stable internet connection
# - Excel 2016 or later to open exported files
#
# Common Issues & Workarounds:
# A. If export times out:
#    - Try reducing the date range
#    - Export in smaller batches
#    - Use off-peak hours
#
# B. If download fails:
#    - Clear browser cache
#    - Use incognito/private mode
#    - Try a different supported browser
#
# Escalation Path:
# If you continue experiencing issues after trying the above steps, please:
# 1. Contact our technical support team at support@company.com
# 2. Include your project ID and export error messages
# 3. For urgent assistance, call our support hotline: 1-800-TECH-HELP
